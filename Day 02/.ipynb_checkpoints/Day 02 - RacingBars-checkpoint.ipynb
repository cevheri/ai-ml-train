# %% [markdown]
# # Racing Bars

# %%
pip install ffmpeg
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bar_chart_race
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('corona_dat.csv')
df.sample(5)
# Out:
#           date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 92   4/23/2020          118       58      253       24       0
# 71    4/2/2020           43       28      167       39       0
# 111  5/12/2020          333       32      341       21       0
# 73    4/4/2020           19       42      133       33       3
# 35   2/26/2020            0        0        0        0       0
#
#      Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay     US  \
# 92                     0        351       76        133  ...       25  33968
# 71                     2         95       97        356  ...       27  32327
# 111                    0        315      218         68  ...       15  20723
# 73                     0        203       34        274  ...       22  39837
# 35                     0          0        0          0  ...        0      6
#
#      Uzbekistan  Venezuela  Vietnam  West Bank and Gaza  Western Sahara  \
# ...

# %%
df3 = df[['date', 'China', 'Italy', 'Brazil', 'Spain', 'US', 'Turkey']]
df3.sample(5)
# Out:
#          date  China  Italy  Brazil  Spain     US  Turkey
# 87  4/18/2020     89   6173    3189    928  41128    5726
# 34  2/25/2020   3244     96       0      4      1       0
# 10   2/1/2020   2196      0       0      1      1       0
# 21  2/12/2020    824      0       0      0      0       0
# 23  2/14/2020   8375      0       0      0      0       0

# %%
df3.set_index('date', inplace=True)

# %%
total = df3.cumsum(axis=0)
total.sample(5)
# Out:
#             China  Italy  Brazil  Spain    US  Turkey
# date
# 3/16/2020  152160  32887     201  10814  4748      18
# 2/16/2020   83034      3       0      4    16       0
# 2/22/2020  102143     65       0      4    20       0
# 2/28/2020  118047    955       1     34    67       0
# 2/5/2020    29118      2       0      1    11       0

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(total, filename='covid19.mp4', figsize=(10,8), title='Cevheri')
# Out:
# /home/cevheri/anaconda3/lib/python3.11/site-packages/bar_chart_race/_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# /home/cevheri/anaconda3/lib/python3.11/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# /home/cevheri/anaconda3/lib/python3.11/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# ...
