# %% [markdown]
# # Machine Learning with Singe Word

# %%
# pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 68.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 20.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 54.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Regression

# %%
from pycaret.regression import*
import pandas as pd

# %%
df = pd.read_pickle('kc_house.pkl')
setup(data=df, target='price')
# Out:
# <style type="text/css">
# #T_514a6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_514a6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_514a6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_514a6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_514a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_514a6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_514a6_row0_col1" class="data row0 col1" >7663</td>
#     </tr>
#     <tr>
#       <th id="T_514a6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_514a6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_514a6_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_514a6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ef37b th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## Classification

# %%
df2 = pd.read_csv('pima-indians-diabetes.csv')

# %%
from pycaret.classification import*

# %%
setup(df2, target='Outcome')
# Out:
# <style type="text/css">
# #T_87d97_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_87d97" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87d97_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_87d97_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87d97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87d97_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_87d97_row0_col1" class="data row0 col1" >6863</td>
#     </tr>
#     <tr>
#       <th id="T_87d97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87d97_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_87d97_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_87d97_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_af043 th {
#   text-align: left;
# }
# ...

# %%
best_model = create_model('lr')
# Out:
# <style type="text/css">
# #T_0a5bd_row10_col0, #T_0a5bd_row10_col1, #T_0a5bd_row10_col2, #T_0a5bd_row10_col3, #T_0a5bd_row10_col4, #T_0a5bd_row10_col5, #T_0a5bd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0a5bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a5bd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0a5bd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0a5bd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0a5bd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0a5bd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0a5bd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0a5bd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(best_model, plot='feature')

# %% [markdown]
# ## Clustering

# %%
df3 = pd.read_excel('cars.xls')
from pycaret.clustering import*
setup(df3)
# Out:
# <style type="text/css">
# #T_391bb_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_391bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_391bb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_391bb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_391bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_391bb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_391bb_row0_col1" class="data row0 col1" >2188</td>
#     </tr>
#     <tr>
#       <th id="T_391bb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_391bb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_391bb_row1_col1" class="data row1 col1" >(804, 13)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans = create_model('kmeans', 4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8797" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8797_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c8797_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c8797_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c8797_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c8797_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c8797_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8797_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8797_row0_col0" class="data row0 col0" >0.4134</td>
#       <td id="T_c8797_row0_col1" class="data row0 col1" >600.9826</td>
# ...

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Elbo

# %%
plot_model(kmeans, plot='elbow')

# %%
plot_model(kmeans, plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
