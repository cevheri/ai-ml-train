# %% [markdown]
# # Auto Computer Vision

# %% [markdown]
# ## Install the Auto Computer Vision Library

# %%
# !pip install cvlib

# %%
# !pip install autocv

# %%
# !pip install opencv-python

# %% [markdown]
# ## Import the Library

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox
# Out:
# 2024-07-28 15:56:23.152045: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-28 15:56:23.232201: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-28 15:56:23.268573: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-28 15:56:23.278717: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
img = cv2.imread('cars.jpg')
plt.imshow(img)

# %%
box, label, count = cvlib.detect_common_objects(img)

# %%
output_image = draw_bbox(img, box, label, count)

# %%
plt.imshow(output_image)

# %%
label
# Out:
# ['car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'car',
#  'person',
#  'car',
#  'car',
#  'car',
#  'car']

# %%
label.count('car')
# Out:
# 11

# %%
img = cv2.imread('g8-1.webp')
plt.imshow(img)

# %%
box, label, count = cvlib.detect_common_objects(img)

# %%
output_image = draw_bbox(img, box, label, count)

# %%
plt.imshow(output_image)

# %%
label
# Out:
# ['person', 'person', 'person', 'person', 'person', 'person', 'tie']

# %%
img = cv2.imread('dogs.jpg')
plt.imshow(img)

# %%
box, label, count = cvlib.detect_common_objects(img)

# %%
output_image = draw_bbox(img, box, label, count)

# %%
plt.imshow(output_image)

# %%
label
# Out:
# ['dog', 'dog', 'dog', 'dog']

# %%
img = cv2.imread('mutfak.jpg')

# %%
plt.imshow(img)

# %%
box, label, count = cvlib.detect_common_objects(img)

# %%
output_image = draw_bbox(img, box, label, count)

# %%
plt.imshow(output_image)

# %%
label
# Out:
# ['chair',
#  'chair',
#  'vase',
#  'chair',
#  'dining table',
#  'chair',
#  'potted plant',
#  'potted plant']
